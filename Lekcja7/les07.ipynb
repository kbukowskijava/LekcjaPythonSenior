# %%
import pandas

# %%
dfp = pandas.read_csv('characters_pages.csv')

# %%
dfp
# Out:
#                                      Link
# 0            /characters/3-d-man-chandler
# 1      /characters/3-d-man-delroy-garrett
# 2          /characters/8-ball-jeff-hagees
# 3              /characters/a-lady-killers
# 4                    /characters/aardwolf
# 5              /characters/abdul-alhazred
# 6                  /characters/aberration
# 7               /characters/abigail-brand
# 8                 /characters/abomination
# 9                     /characters/abraxas
# 10              /characters/absorbing-man
# 11                      /characters/abyss
# 12    /characters/abyss-age-of-apocalypse
# 13                /characters/abyss-alien
# 14            /characters/ace-g-r-a-m-p-a
# 15                     /characters/achebe
# 16         /characters/acrobat-carl-zante
# 17                   /characters/acroyear
# 18               /characters/adam-destine
# 19         /characters/adam-ii-earth-8206
# 20                  /characters/adam-mann
# ...

# %%
df = pandas.read_csv('characters_dataset.csv')

# %%
df.shape
# Out:
# (35, 7)

# %%
df
# Out:
#                                            Name  \
# 0        Charles Chandler & Hal Chandler3-D Man
# 1                    Delroy Garrett, Jr.3-D Man
# 2                             Jeff Hagees8-Ball
# 3                                  Clair MooreA
# 4                               Chon LiAardwolf
# 5                   Abd-el-HazredAbdul Alhazred
# 6                        Rana PhilipsAberration
# 7   Abigail (last name unrevealed)Abigail Brand
# 8                       Emil BlonskyAbomination
# 9                                       Abraxas
# 10            Carl "Crusher" CreelAbsorbing Man
# 11                             Nils StygerAbyss
# 12                             Nils StygerAbyss
# 13                     Alien, Nova VillainAbyss
# 14                              G.R.A.M.P.A.Ace
# 15                                UnknownAchebe
# 16                            Carl ZanteAcrobat
# 17                                     Acroyear
# ...

# %%
df.fillna('')
# Out:
#                                            Name  \
# 0        Charles Chandler & Hal Chandler3-D Man
# 1                    Delroy Garrett, Jr.3-D Man
# 2                             Jeff Hagees8-Ball
# 3                                  Clair MooreA
# 4                               Chon LiAardwolf
# 5                   Abd-el-HazredAbdul Alhazred
# 6                        Rana PhilipsAberration
# 7   Abigail (last name unrevealed)Abigail Brand
# 8                       Emil BlonskyAbomination
# 9                                       Abraxas
# 10            Carl "Crusher" CreelAbsorbing Man
# 11                             Nils StygerAbyss
# 12                             Nils StygerAbyss
# 13                     Alien, Nova VillainAbyss
# 14                              G.R.A.M.P.A.Ace
# 15                                UnknownAchebe
# 16                            Carl ZanteAcrobat
# 17                                     Acroyear
# ...
